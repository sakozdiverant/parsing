# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

columns = ['Бренд','Тип устройства', 'Модель', 'Алматы',
           'Алатау', 'Астана', 'Шымкент', 'Караганда',
           'Pозница', 'Золото', 'Платина', 'Бриллиант']
df = pd.DataFrame(columns=columns)
brends = ['hiwatch', 'hikvision', 'ezviz', 'ruijie',
         'hikmicro', 'volta', 'uniview', 'umbrella',
         'seagate', 'western_digital']

login_url = "https://b2b.barlau.kz/?login=yes"
data = {
	"AUTH_FORM": "Y",
	"TYPE": "AUTH",
	"USER_LOGIN": "altexkz@mail.ru",
	"USER_PASSWORD": "ezVnkc"
}
session = requests.Session()
session.post(url=login_url, data=data)
session = requests.Session()

# Отправляем POST-запрос для авторизации
login_response = session.post(login_url, data=data)

# Проверяем успешность авторизации
if login_response.status_code == 200 and "logout" in login_response.text.lower():
    print("Авторизация прошла успешно!")
else:
    print("Ошибка авторизации. Проверьте логин и пароль.")
    exit()
# Out:
# Авторизация прошла успешно!

# %%
def make_tab(brend, url, session=session):
    resp = session.get(url)
    soup = BeautifulSoup(resp.text, "html.parser")
    divs = soup.find_all("div", class_="product-card-column")
    for div in divs:
        camera = {}
        # Извлекаем значение атрибута title
        #product-card-column__image-wrapper
        title = div.find("a", class_="product-card-column__title").text.strip()
        type_title = div.find("div", class_="product-card-column__data-wrapper-outer__type").text.strip()
        citys_quantity = div.find_all("p", class_="dop-info__item")
        camera['Бренд'] = brend
        camera['Тип устройства'] = " ".join(type_title.split(' ')[:3])
        camera['Модель'] = title
        for city in citys_quantity:
            city_q = city.find("span", class_="dop-info__item-title").text.strip()
            quantity = city.find("span", class_="dop-info__item-value").text.strip()
            quantity = quantity.replace("&gt;", ">").strip()
            camera[city_q] = quantity
        df.loc[len(df)] = camera

# %%
for brend in brends:
    page = 1  # Начинаем с первой страницы
    while True:
 
        if page == 1:
            url = f"http://b2b.barlau.kz/catalog/{brend}/"
        else:
            url = f"http://b2b.barlau.kz/catalog/{brend}/?PAGEN_2={page}"

        resp = session.get(url)
        soup = BeautifulSoup(resp.text, "html.parser") 
        if page != 1:
            try:
                page_now = int(soup.find("span", class_="block_page_current").text.strip()) 
                print(page_now, '=', page)     
                if int(page_now) != page:
                    print(f"Cтранице {page - 1} для {brend}. Была последней.")
                    break
            except:
                break
        
        print(f"Проверка URL: {url}")

        # Если страница невалидная или недоступна, выходим из цикла
        if resp.status_code != 200:
            print(f"Нет данных на странице {page} для {brend}. Завершаем.")
            break

        # Обработка страницы (пример)
        print(f"Обработка страницы {page} для бренда {brend}...")

        # Увеличиваем номер страницы
        page += 1
        make_tab(brend, url)
# Out:
# Проверка URL: http://b2b.barlau.kz/catalog/hiwatch/
# Обработка страницы 1 для бренда hiwatch...
# 2 = 2
# Проверка URL: http://b2b.barlau.kz/catalog/hiwatch/?PAGEN_2=2
# Обработка страницы 2 для бренда hiwatch...
# 3 = 3
# Проверка URL: http://b2b.barlau.kz/catalog/hiwatch/?PAGEN_2=3
# Обработка страницы 3 для бренда hiwatch...
# 4 = 4
# Проверка URL: http://b2b.barlau.kz/catalog/hiwatch/?PAGEN_2=4
# Обработка страницы 4 для бренда hiwatch...
# 5 = 5
# Проверка URL: http://b2b.barlau.kz/catalog/hiwatch/?PAGEN_2=5
# Обработка страницы 5 для бренда hiwatch...
# 6 = 6
# Проверка URL: http://b2b.barlau.kz/catalog/hiwatch/?PAGEN_2=6
# Обработка страницы 6 для бренда hiwatch...
# 7 = 7
# Проверка URL: http://b2b.barlau.kz/catalog/hiwatch/?PAGEN_2=7
# Обработка страницы 7 для бренда hiwatch...
# 8 = 8
# Проверка URL: http://b2b.barlau.kz/catalog/hiwatch/?PAGEN_2=8
# Обработка страницы 8 для бренда hiwatch...
# 9 = 9
# Проверка URL: http://b2b.barlau.kz/catalog/hiwatch/?PAGEN_2=9
# Обработка страницы 9 для бренда hiwatch...
# 10 = 10
# Проверка URL: http://b2b.barlau.kz/catalog/hiwatch/?PAGEN_2=10
# Обработка страницы 10 для бренда hiwatch...
# 11 = 11
# Проверка URL: http://b2b.barlau.kz/catalog/hiwatch/?PAGEN_2=11
# Обработка страницы 11 для бренда hiwatch...
# 1 = 12
# Cтранице 11 для hiwatch. Была последней.
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/
# Обработка страницы 1 для бренда hikvision...
# 2 = 2
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=2
# Обработка страницы 2 для бренда hikvision...
# 3 = 3
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=3
# Обработка страницы 3 для бренда hikvision...
# 4 = 4
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=4
# Обработка страницы 4 для бренда hikvision...
# 5 = 5
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=5
# Обработка страницы 5 для бренда hikvision...
# 6 = 6
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=6
# Обработка страницы 6 для бренда hikvision...
# 7 = 7
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=7
# Обработка страницы 7 для бренда hikvision...
# 8 = 8
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=8
# Обработка страницы 8 для бренда hikvision...
# 9 = 9
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=9
# Обработка страницы 9 для бренда hikvision...
# 10 = 10
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=10
# Обработка страницы 10 для бренда hikvision...
# 11 = 11
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=11
# Обработка страницы 11 для бренда hikvision...
# 12 = 12
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=12
# Обработка страницы 12 для бренда hikvision...
# 13 = 13
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=13
# Обработка страницы 13 для бренда hikvision...
# 14 = 14
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=14
# Обработка страницы 14 для бренда hikvision...
# 15 = 15
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=15
# Обработка страницы 15 для бренда hikvision...
# 16 = 16
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=16
# Обработка страницы 16 для бренда hikvision...
# 17 = 17
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=17
# Обработка страницы 17 для бренда hikvision...
# 18 = 18
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=18
# Обработка страницы 18 для бренда hikvision...
# 19 = 19
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=19
# Обработка страницы 19 для бренда hikvision...
# 20 = 20
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=20
# Обработка страницы 20 для бренда hikvision...
# 21 = 21
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=21
# Обработка страницы 21 для бренда hikvision...
# 22 = 22
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=22
# Обработка страницы 22 для бренда hikvision...
# 23 = 23
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=23
# Обработка страницы 23 для бренда hikvision...
# 24 = 24
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=24
# Обработка страницы 24 для бренда hikvision...
# 25 = 25
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=25
# Обработка страницы 25 для бренда hikvision...
# 26 = 26
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=26
# Обработка страницы 26 для бренда hikvision...
# 27 = 27
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=27
# Обработка страницы 27 для бренда hikvision...
# 28 = 28
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=28
# Обработка страницы 28 для бренда hikvision...
# 29 = 29
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=29
# Обработка страницы 29 для бренда hikvision...
# 30 = 30
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=30
# Обработка страницы 30 для бренда hikvision...
# 31 = 31
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=31
# Обработка страницы 31 для бренда hikvision...
# 32 = 32
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=32
# Обработка страницы 32 для бренда hikvision...
# 33 = 33
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=33
# Обработка страницы 33 для бренда hikvision...
# 34 = 34
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=34
# Обработка страницы 34 для бренда hikvision...
# 35 = 35
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=35
# Обработка страницы 35 для бренда hikvision...
# 36 = 36
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=36
# Обработка страницы 36 для бренда hikvision...
# 37 = 37
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=37
# Обработка страницы 37 для бренда hikvision...
# 38 = 38
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=38
# Обработка страницы 38 для бренда hikvision...
# 39 = 39
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=39
# Обработка страницы 39 для бренда hikvision...
# 40 = 40
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=40
# Обработка страницы 40 для бренда hikvision...
# 41 = 41
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=41
# Обработка страницы 41 для бренда hikvision...
# 42 = 42
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=42
# Обработка страницы 42 для бренда hikvision...
# 43 = 43
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=43
# Обработка страницы 43 для бренда hikvision...
# 44 = 44
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=44
# Обработка страницы 44 для бренда hikvision...
# 45 = 45
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=45
# Обработка страницы 45 для бренда hikvision...
# 46 = 46
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=46
# Обработка страницы 46 для бренда hikvision...
# 47 = 47
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=47
# Обработка страницы 47 для бренда hikvision...
# 48 = 48
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=48
# Обработка страницы 48 для бренда hikvision...
# 49 = 49
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=49
# Обработка страницы 49 для бренда hikvision...
# 50 = 50
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=50
# Обработка страницы 50 для бренда hikvision...
# 51 = 51
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=51
# Обработка страницы 51 для бренда hikvision...
# 52 = 52
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=52
# Обработка страницы 52 для бренда hikvision...
# 53 = 53
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=53
# Обработка страницы 53 для бренда hikvision...
# 54 = 54
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=54
# Обработка страницы 54 для бренда hikvision...
# 55 = 55
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=55
# Обработка страницы 55 для бренда hikvision...
# 56 = 56
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=56
# Обработка страницы 56 для бренда hikvision...
# 57 = 57
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=57
# Обработка страницы 57 для бренда hikvision...
# 58 = 58
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=58
# Обработка страницы 58 для бренда hikvision...
# 59 = 59
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=59
# Обработка страницы 59 для бренда hikvision...
# 60 = 60
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=60
# Обработка страницы 60 для бренда hikvision...
# 61 = 61
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=61
# Обработка страницы 61 для бренда hikvision...
# 62 = 62
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=62
# Обработка страницы 62 для бренда hikvision...
# 63 = 63
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=63
# Обработка страницы 63 для бренда hikvision...
# 64 = 64
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=64
# Обработка страницы 64 для бренда hikvision...
# 65 = 65
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=65
# Обработка страницы 65 для бренда hikvision...
# 66 = 66
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=66
# Обработка страницы 66 для бренда hikvision...
# 67 = 67
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=67
# Обработка страницы 67 для бренда hikvision...
# 68 = 68
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=68
# Обработка страницы 68 для бренда hikvision...
# 69 = 69
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=69
# Обработка страницы 69 для бренда hikvision...
# 70 = 70
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=70
# Обработка страницы 70 для бренда hikvision...
# 71 = 71
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=71
# Обработка страницы 71 для бренда hikvision...
# 72 = 72
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=72
# Обработка страницы 72 для бренда hikvision...
# 73 = 73
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=73
# Обработка страницы 73 для бренда hikvision...
# 74 = 74
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=74
# Обработка страницы 74 для бренда hikvision...
# 75 = 75
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=75
# Обработка страницы 75 для бренда hikvision...
# 76 = 76
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=76
# Обработка страницы 76 для бренда hikvision...
# 77 = 77
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=77
# Обработка страницы 77 для бренда hikvision...
# 78 = 78
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=78
# Обработка страницы 78 для бренда hikvision...
# 79 = 79
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=79
# Обработка страницы 79 для бренда hikvision...
# 80 = 80
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=80
# Обработка страницы 80 для бренда hikvision...
# 81 = 81
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=81
# Обработка страницы 81 для бренда hikvision...
# 82 = 82
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=82
# Обработка страницы 82 для бренда hikvision...
# 83 = 83
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=83
# Обработка страницы 83 для бренда hikvision...
# 84 = 84
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=84
# Обработка страницы 84 для бренда hikvision...
# 85 = 85
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=85
# Обработка страницы 85 для бренда hikvision...
# 86 = 86
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=86
# Обработка страницы 86 для бренда hikvision...
# 87 = 87
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=87
# Обработка страницы 87 для бренда hikvision...
# 88 = 88
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=88
# Обработка страницы 88 для бренда hikvision...
# 89 = 89
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=89
# Обработка страницы 89 для бренда hikvision...
# 90 = 90
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=90
# Обработка страницы 90 для бренда hikvision...
# 91 = 91
# Проверка URL: http://b2b.barlau.kz/catalog/hikvision/?PAGEN_2=91
# Обработка страницы 91 для бренда hikvision...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 34
#      32 # Увеличиваем номер страницы
#      33 page += 1
# ---> 34 make_tab(brend, url)
#
# Cell In[30], line 9, in make_tab(brend, url, session)
#       6 camera = {}
#       7 # Извлекаем значение атрибута title
#       8 #product-card-column__image-wrapper
# ----> 9 title = div.find("a", class_="product-card-column__title").text.strip()
#      10 type_title = div.find("div", class_="product-card-column__data-wrapper-outer__type").text.strip()
#      11 citys_quantity = div.find_all("p", class_="dop-info__item")
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
df.to_excel("cameras.xlsx", index=False)

# %%
df[40:50]
# Out:
#         Бренд             Тип устройства                              Модель  \
# 40  hikvision         WiFi Точка доступа                       DS-3WAP522-SI
# 41  hikvision               WiFi Роутер                            DS-3WR15X
# 42  hikvision       IP Камера, купольная    iDS-2CD7146G0/H-IZS (2.8-12.0mm)
# 43  hikvision       IP Камера, купольная  iDS-2CD7146G0/H-IZHSY (2.8-12.0mm)
# 44  hikvision  IP Камера, цилиндрическая           DS-2CD3046G2H-LIU (2.8mm)
# 45  hikvision         WiFi Точка доступа                      DS-3WAP622G-SI
# 46  hikvision       Камера, портативная                    DS-MCW409/32G/GLE
# 47  hikvision      Комплекс фиксации для                       iDS-TVJ860-IR
# 48  hikvision       Камера, портативная                 DS-MCW407/32G/GLE(A)
# 49  hikvision            Маршрутизатор                        DS-3WG210GP-SI
#
#    Алматы Алатау Астана Шымкент Караганда  Pозница  Золото Платина Бриллиант
# 40   1 шт   0 шт   0 шт    0 шт      0 шт   50 325  35 227  30 195    27 679
# 41   1 шт   0 шт   0 шт    0 шт      0 шт   22 029  17 623  16 522    15 420
# 42   3 шт   0 шт   0 шт    0 шт      0 шт      NaN     NaN     NaN       NaN
# 43   0 шт   9 шт   0 шт    0 шт      0 шт      NaN     NaN     NaN       NaN
# 44   0 шт   5 шт   0 шт    0 шт      0 шт      NaN     NaN     NaN       NaN
# 45   2 шт   0 шт   0 шт    0 шт      0 шт   77 922  54 545  46 753    42 857
# 46   0 шт   1 шт   0 шт    0 шт      0 шт      NaN     NaN     NaN       NaN
# 47   0 шт   1 шт   0 шт    0 шт      0 шт      NaN     NaN     NaN       NaN
# 48   0 шт   1 шт   0 шт    0 шт      0 шт      NaN     NaN     NaN       NaN
# 49   3 шт   0 шт   0 шт    0 шт      0 шт  102 814  71 970  61 688    56 548
